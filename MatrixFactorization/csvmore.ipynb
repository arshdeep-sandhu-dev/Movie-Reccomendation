# %%
import numpy as np
import pycuda.driver as cuda
import pycuda.autoinit
import ctypes
from pycuda.compiler import SourceModule
import time
#define CLIP(x, min, max) (fminf(fmaxf(x, min), max))

N = 50  # Increase to capture more user preferences
  # Adjust as needed
totalMoviesUsingPerPerson=400

# Define the Row structure
class Row(ctypes.Structure):
    _fields_ = [("col1", ctypes.c_int), ("col2", ctypes.c_float)]
class RowTest(ctypes.Structure):
    _fields_ = [("col1", ctypes.c_int), ("col2", ctypes.c_float),("user",ctypes.c_int)]



# Create some example row data
rows_data = []

# Define the parallel matrix multiplication kernel
kernel_code = """
struct Row {
    int col1;
    float col2;
};

__global__ void matmul(float *A, float *B, int N, int raters, int movies, Row *rows, float learning_rate) {
    int row = blockIdx.y * blockDim.y + threadIdx.y;  // Movies
    int col = blockIdx.x * blockDim.x + threadIdx.x;  // Raters
    int totalMoviesUsingPerPerson=400;
    if (row < movies && col < raters && col > 0 && row > 0) {
        int found = 0;
        float actual_rating = 0.0;

        // Find actual rating from stored data
        
        int start = 0;
        int end = totalMoviesUsingPerPerson-1;  // Fix here to prevent out-of-bounds access
        while (start <= end) {
            int mid = start + (end - start) / 2;
            if (rows[(col - 1) * totalMoviesUsingPerPerson + mid].col1 == row){
                found = 1;
                actual_rating = rows[(col - 1) * totalMoviesUsingPerPerson + mid].col2;
                break;
            } else if (rows[(col - 1) * totalMoviesUsingPerPerson + mid].col1==0 || rows[(col - 1) * totalMoviesUsingPerPerson + mid].col1 > row) {
                end = mid - 1;
            } else {
                start = mid + 1;
            }
        }

        if (found) {
            float predicted_rating = 0.0;
            for (int k = 0; k < N; k++) {
                predicted_rating += A[row * N + k] * B[k * raters + col];
            }
            
            float error = actual_rating - predicted_rating;
            
            for (int k = 0; k < N; k++) {
                float lambda = 0.01;
                float regularization = lambda * (A[row * N + k] * A[row * N + k] + B[k * raters + col] * B[k * raters + col]);
                float grad_A = -2.0 * error * B[k * raters + col] + regularization;
                float grad_B = -2.0 * error * A[row * N + k] + regularization;
                                
                // Apply updates
                atomicAdd(&A[row * N + k], -learning_rate * grad_A);
                atomicAdd(&B[k * raters + col], -learning_rate * grad_B);

                atomicExch(&A[row * N + k], fminf(fmaxf(A[row * N + k], -1.0f), 1.0f));
                atomicExch(&B[k * raters + col], fminf(fmaxf(B[k * raters + col], -1.0f), 1.0f));
            }

            

        }

    }
}

"""

mod = SourceModule(kernel_code)


def read_csv_to_list_rating(file_path):
    """Read a CSV file into a list of lists with specific column types."""
    with open(file_path, 'r', encoding='utf-8') as file:
        matrix = []
        header = file.readline().strip().split(',')
        for line in file:
            values = line.strip().split(',')
            row = [int(values[0]), int(values[1]), float(values[2]), int(values[3])]
            matrix.append(row)
        return header, matrix

def read_csv_to_list_movies(file_path):
    """Read a CSV file into a list of lists with specific column types."""
    with open(file_path, 'r', encoding='utf-8') as file:
        matrix = []
        header = file.readline().strip().split(',')
        for line in file:
            values = line.strip().split(',')
            row = [int(values[0]), str(values[1]), str(values[2])]
            matrix.append(row)
        return header, matrix

headerRating, matrixrating = read_csv_to_list_rating('ratings.csv')
headerMovies, matrixMovies = read_csv_to_list_movies('movies.csv')

totalRaters = int(matrixrating[-1][0])+1  # total rows
totalMovies = int(matrixMovies[-1][0])+1
print(totalRaters)
print(totalMovies)



d = {}
# row 0 is userID

for row in matrixrating:
    if row[0] not in d:
        d[row[0]] = []
    else:
        d[row[0]].append(list(row[1:4]))

for key, val in d.items():
    d[key] = sorted(val, key=lambda x: x[2])

for key, val in d.items():
    d[key] = d[key][::-1]

newD = {}
for key, val in d.items():
    newD[key] = sorted(d[key][:totalMoviesUsingPerPerson], key=lambda x: x[0])

totalUsers = len(newD)
total_rat_us=0
rows_data = []
for i in range(1, (len(newD) + 1)):
    row = newD[i]
    for j in range(totalMoviesUsingPerPerson):
        if j < len(row):
            total_rat_us+=1
            rows_data.append(Row(row[j][0], row[j][1]))
        else:
            rows_data.append(Row(0, 0.0))
print("Total rating used ",end="")
print(total_rat_us)
matrixAMovies = np.zeros((totalMovies, N), dtype=np.float32)
matrixBUsers = np.zeros((N, totalRaters), dtype=np.float32)


# Fill matrices with random values in the range -0.01 to 0.01
matrixAMovies = np.random.uniform(-0.1, 0.1, size=(totalMovies, N)).astype(np.float32)
matrixBUsers = np.random.uniform(-0.1, 0.1, size=(N, totalRaters)).astype(np.float32)

matrixAMovies = np.ascontiguousarray(matrixAMovies, dtype=np.float32)
matrixBUsers = np.ascontiguousarray(matrixBUsers, dtype=np.float32)

A_gpu_matrixAMovies = cuda.mem_alloc(matrixAMovies.nbytes)
B_gpu_matrixBUsers = cuda.mem_alloc(matrixBUsers.nbytes)

if A_gpu_matrixAMovies is None or B_gpu_matrixBUsers is None:
    print("Damn")

rows = (Row * len(rows_data))(*rows_data)

# Allocate memory on the GPU for the rows
rows_gpu = cuda.mem_alloc(ctypes.sizeof(rows))
if rows_gpu is None:
    print("damn")

# Transfer the rows data to the GPU
cuda.memcpy_htod(rows_gpu, rows)

cuda.memcpy_htod(A_gpu_matrixAMovies, matrixAMovies)
cuda.memcpy_htod(B_gpu_matrixBUsers, matrixBUsers)


matmul = mod.get_function("matmul")

# Define grid and block sizes
block_size = (16, 16, 1)  # 16x16 threads per block
grid_size = ((totalRaters + block_size[1] - 1) // block_size[1], 
             (totalMovies + block_size[0] - 1) // block_size[0])


print(f"Matrix A shape: {matrixAMovies.shape}")
print(f"Matrix B shape: {matrixBUsers.shape}")

# Calculate the shared memory size
shared_mem_size = ctypes.sizeof(Row) * min(totalRaters * totalMoviesUsingPerPerson, block_size[0] * block_size[1])
# Run the parallel CUDA kernel
cuda.Context.synchronize()  # Ensure synchronization before execution]
print("A GPU Memory Address:", int(A_gpu_matrixAMovies))
print("B GPU Memory Address:", int(B_gpu_matrixBUsers))
print("Rows GPU Memory Address:", int(rows_gpu))

# start_time = time.time()
# matmul(A_gpu_matrixAMovies, B_gpu_matrixBUsers, np.int32(N), np.int32(totalRaters), np.int32(totalMovies), rows_gpu,learning_rate,
#        block=block_size, grid=grid_size, shared=shared_mem_size)
# cuda.Context.synchronize()  # Ensure synchronization after execution
# end_time = time.time()
# # Copy result back to CPU

# # 🚀 First, copy updated A and B back to CPU
# matrixAMovies_result = np.empty_like(matrixAMovies)
# matrixBUsers_result = np.empty_like(matrixBUsers)

# cuda.memcpy_dtoh(matrixAMovies_result, A_gpu_matrixAMovies)
# cuda.memcpy_dtoh(matrixBUsers_result, B_gpu_matrixBUsers)
# rows_result = np.zeros(len(rows_data), dtype=[('col1', np.int32), ('col2', np.float32)])
# cuda.memcpy_dtoh(rows_result, rows_gpu)
# Out:
# 200949
# 292758
# Total rating used 24704769
# Matrix A shape: (292758, 50)
# Matrix B shape: (50, 200949)
# A GPU Memory Address: 47343206400
# B GPU Memory Address: 47401926656
# Rows GPU Memory Address: 47443869696

# %%
epochs = 15  # Number of iterations

initial_lr = np.float32(0.001)  # Start slightly lower than 0.003
decay_factor = np.float32(0.95)   # Reduce by 10% every 5 epochs
decay_step = 5

min_lr = np.float32(0.0005)  # Ensure learning rate never goes too low
def normalize_embeddings(matrix):
    norms = np.linalg.norm(matrix, axis=1, keepdims=True)  # Compute row-wise norm
    norms[norms == 0] = 1  # Prevent division by zero
    return matrix / norms
learning_rate = np.float32(0.001)
matrixAMovies_result=None
matrixBUsers_result=None
rows_result=None
for epoch in range(epochs):
    # learning_rate = np.float32(initial_lr * np.exp(-0.05 * epoch))
    if epoch==5:
        learning_rate = np.float32(0.0005)


    matrixAMovies_result = np.empty_like(matrixAMovies)
    matrixBUsers_result = np.empty_like(matrixBUsers)
    rows_result = np.zeros(len(rows_data), dtype=[('col1', np.int32), ('col2', np.float32)])
    start_time = time.time()
    # if epoch % 5 == 0:  # Every 5 epochs, reduce learning rate
    #     learning_rate *= 0.9  # Reduce by 10%

    matmul(A_gpu_matrixAMovies, B_gpu_matrixBUsers, np.int32(N), np.int32(totalRaters),
           np.int32(totalMovies), rows_gpu, learning_rate, block=block_size, grid=grid_size,
           shared=shared_mem_size)
    
    cuda.Context.synchronize()  # Wait for CUDA execution

    # Copy updated matrices and rows back to CPU
    cuda.memcpy_dtoh(matrixAMovies_result, A_gpu_matrixAMovies)
    cuda.memcpy_dtoh(matrixBUsers_result, B_gpu_matrixBUsers)
    cuda.memcpy_dtoh(rows_result, rows_gpu)


    if np.isnan(matrixAMovies_result).any() or np.isnan(matrixBUsers_result).any():
        print("Error: NaN detected in A or B matrix!")
        exit()

    if np.isinf(matrixAMovies_result).any() or np.isinf(matrixBUsers_result).any():
        print("Error: Inf detected in A or B matrix!")
        exit()

    # Compute loss
    mse = 0
    count = 0
    end_time = time.time()
    for i in range(len(rows_result)):
        if rows_result[i]['col1'] > 0:
            actual = rows_result[i]['col2']
            predicted = np.dot(matrixAMovies_result[rows_result[i]['col1'], :], matrixBUsers_result[:, i // totalMoviesUsingPerPerson])
            
            if np.isnan(predicted) or np.isinf(predicted):
                print(f"Error in prediction: row {i}, actual {actual}, predicted {predicted}")
                exit()

            mse += (actual - predicted) ** 2
            count += 1

    mse = mse / count if count > 0 else float('inf')  # Avoid division by zero

    
    print(f"Epoch {epoch+1}/{epochs}, MSE: {mse:.5f}, Time: {end_time - start_time:.5f} sec")





# Track execution time for CUDA

print(f"Parallel GPU Execution Time (CUDA): {end_time - start_time:.5f} seconds")


user_id = 2  # Example user (change as needed)
movie_id = rows_result[17]['col1']  # Get the movie ID from rows_result

predicted = np.dot(matrixAMovies_result[movie_id, :], matrixBUsers_result[:, user_id])
print(f"Predicted rating for user {user_id} and movie {movie_id}: {predicted:.2f}")







listUnused =[]
for m in (matrixrating[55:180]):
    hit=0
    for i in range(1*totalMoviesUsingPerPerson,2*totalMoviesUsingPerPerson):
        if int(m[1]) ==int(rows_data[i].col1):
            
            hit=1
            break
    if hit==0:
        listUnused.append([int(m[1]),int(m[2])])

listUnused2 =[]
for m in (matrixrating[55:180]):
    hit=0
    for i in range(1*totalMoviesUsingPerPerson,2*totalMoviesUsingPerPerson):
        if int(m[1]) ==int(rows_data[i].col1):
            
            hit=1
            break
    if hit==1:
        listUnused2.append([int(m[1]),int(m[2])])


for i in range(len(listUnused)):
    user_id = 2  # Example user (change as needed)
    movie_id = listUnused[i][0]  # Get the movie ID from rows_result
    actualPred = listUnused[i][1]
    predicted = np.dot(matrixAMovies_result[movie_id, :], matrixBUsers_result[:, user_id])
    print(f"Predicted rating for user {user_id} and movie {movie_id}: {predicted:.2f}     Actual {actualPred}")

print()
# Out:
# Epoch 1/15, MSE: 4.92449, Time: 11.53781 sec
# Epoch 2/15, MSE: 2.07525, Time: 10.49408 sec
# Epoch 3/15, MSE: 1.64076, Time: 10.51764 sec
# Epoch 4/15, MSE: 1.49200, Time: 10.46308 sec
# Epoch 5/15, MSE: 1.41846, Time: 10.48464 sec
# Epoch 6/15, MSE: 1.38882, Time: 10.46994 sec
# Epoch 7/15, MSE: 1.36530, Time: 10.38716 sec
# Epoch 8/15, MSE: 1.35127, Time: 10.82996 sec
# Epoch 9/15, MSE: 1.34157, Time: 10.96828 sec
# Epoch 10/15, MSE: 1.33480, Time: 10.46483 sec
# Epoch 11/15, MSE: 1.33001, Time: 10.53042 sec
# Epoch 12/15, MSE: 1.32675, Time: 10.90420 sec
# Epoch 13/15, MSE: 1.32446, Time: 10.86747 sec
# Epoch 14/15, MSE: 1.32315, Time: 11.00522 sec
# Epoch 15/15, MSE: 1.32261, Time: 10.48757 sec
# Parallel GPU Execution Time (CUDA): 10.48757 seconds
# Predicted rating for user 2 and movie 307: 4.78
# Predicted rating for user 2 and movie 1199: 4.28     Actual 2
# Predicted rating for user 2 and movie 1200: 4.38     Actual 5
# Predicted rating for user 2 and movie 1203: 4.53     Actual 5
# Predicted rating for user 2 and movie 1204: 4.65     Actual 1
# Predicted rating for user 2 and movie 1208: 4.32     Actual 5
# Predicted rating for user 2 and movie 1210: 4.54     Actual 2
# Predicted rating for user 2 and movie 1211: 4.42     Actual 2
# Predicted rating for user 2 and movie 1213: 4.25     Actual 5
# Predicted rating for user 2 and movie 1217: 4.51     Actual 5
# Predicted rating for user 2 and movie 1221: 4.57     Actual 5
# Predicted rating for user 2 and movie 1225: 4.42     Actual 4
# Predicted rating for user 2 and movie 1228: 4.42     Actual 5
# Predicted rating for user 2 and movie 1233: 4.44     Actual 5
# Predicted rating for user 2 and movie 1234: 4.58     Actual 5
# Predicted rating for user 2 and movie 1236: 4.67     Actual 4
# Predicted rating for user 2 and movie 1242: 4.48     Actual 1
# Predicted rating for user 2 and movie 1247: 4.51     Actual 5
# Predicted rating for user 2 and movie 1259: 4.19     Actual 4
# Predicted rating for user 2 and movie 1262: 4.65     Actual 4
# Predicted rating for user 2 and movie 1263: 4.27     Actual 5
# Predicted rating for user 2 and movie 1270: 4.34     Actual 5
# Predicted rating for user 2 and movie 1272: 4.52     Actual 5
# Predicted rating for user 2 and movie 1276: 4.41     Actual 3
# Predicted rating for user 2 and movie 1288: 4.22     Actual 4
# Predicted rating for user 2 and movie 1296: 4.66     Actual 3
# Predicted rating for user 2 and movie 1297: 3.97     Actual 5
# Predicted rating for user 2 and movie 1304: 4.41     Actual 3
# Predicted rating for user 2 and movie 1357: 4.35     Actual 1
# Predicted rating for user 2 and movie 1392: 4.25     Actual 4
# Predicted rating for user 2 and movie 1406: 3.72     Actual 2
# Predicted rating for user 2 and movie 1653: 3.62     Actual 4
# Predicted rating for user 2 and movie 1693: 3.99     Actual 5
# Predicted rating for user 2 and movie 1719: 4.29     Actual 5
# Predicted rating for user 2 and movie 1721: 3.95     Actual 5
# Predicted rating for user 2 and movie 1748: 3.44     Actual 5
# Predicted rating for user 2 and movie 1784: 4.31     Actual 1
# Predicted rating for user 2 and movie 1810: 3.83     Actual 3
# Predicted rating for user 2 and movie 1885: 4.01     Actual 4
# Predicted rating for user 2 and movie 1923: 4.00     Actual 2
# Predicted rating for user 2 and movie 1939: 4.64     Actual 5
# Predicted rating for user 2 and movie 1944: 4.27     Actual 2
# Predicted rating for user 2 and movie 1952: 4.23     Actual 4
# Predicted rating for user 2 and movie 1960: 4.09     Actual 1
# Predicted rating for user 2 and movie 1961: 4.15     Actual 1
# Predicted rating for user 2 and movie 1965: 3.74     Actual 3
# Predicted rating for user 2 and movie 1968: 3.80     Actual 5
# Predicted rating for user 2 and movie 2020: 4.22     Actual 5
# Predicted rating for user 2 and movie 2025: 3.73     Actual 5
# Predicted rating for user 2 and movie 2028: 4.13     Actual 3
# Predicted rating for user 2 and movie 2064: 4.23     Actual 3
# Predicted rating for user 2 and movie 2067: 4.42     Actual 1
# Predicted rating for user 2 and movie 2109: 3.72     Actual 1
# Predicted rating for user 2 and movie 2125: 4.22     Actual 4
# Predicted rating for user 2 and movie 2232: 3.54     Actual 3
# Predicted rating for user 2 and movie 2243: 3.95     Actual 1
# Predicted rating for user 2 and movie 2247: 3.58     Actual 5
# Predicted rating for user 2 and movie 2268: 4.14     Actual 1
# Predicted rating for user 2 and movie 2312: 4.19     Actual 1
# Predicted rating for user 2 and movie 2313: 4.24     Actual 5
# Predicted rating for user 2 and movie 2324: 4.13     Actual 1
# Predicted rating for user 2 and movie 2329: 3.80     Actual 5
# Predicted rating for user 2 and movie 2336: 4.09     Actual 5
# Predicted rating for user 2 and movie 2352: 4.09     Actual 3
# Predicted rating for user 2 and movie 2396: 4.51     Actual 5
# Predicted rating for user 2 and movie 2407: 3.98     Actual 1
# Predicted rating for user 2 and movie 2424: 3.92     Actual 1
# Predicted rating for user 2 and movie 2502: 3.72     Actual 3
# Predicted rating for user 2 and movie 2520: 3.39     Actual 5
# Predicted rating for user 2 and movie 2529: 3.91     Actual 5
# Predicted rating for user 2 and movie 2599: 4.02     Actual 5
# Predicted rating for user 2 and movie 2640: 3.76     Actual 5
# Predicted rating for user 2 and movie 2690: 4.00     Actual 3
# Predicted rating for user 2 and movie 2712: 2.98     Actual 1
# Predicted rating for user 2 and movie 2724: 3.40     Actual 1
# Predicted rating for user 2 and movie 2797: 4.34     Actual 5
# Predicted rating for user 2 and movie 2882: 2.92     Actual 1
# Predicted rating for user 2 and movie 2890: 3.54     Actual 4
# Predicted rating for user 2 and movie 2918: 4.00     Actual 4
# Predicted rating for user 2 and movie 2944: 4.00     Actual 4
# Predicted rating for user 2 and movie 2966: 4.10     Actual 1
# Predicted rating for user 2 and movie 2973: 4.15     Actual 5
# Predicted rating for user 2 and movie 2985: 3.44     Actual 5
# Predicted rating for user 2 and movie 2997: 3.58     Actual 4
# Predicted rating for user 2 and movie 3030: 4.31     Actual 4
# Predicted rating for user 2 and movie 3078: 3.66     Actual 2
# Predicted rating for user 2 and movie 3088: 4.17     Actual 3
# Predicted rating for user 2 and movie 31: 4.33     Actual 5

# %%
print("HERE")
print()
for i in range(len(listUnused2)):
    user_id = 2  # Example user (change as needed)
    movie_id = listUnused2[i][0]  # Get the movie ID from rows_result
    actualPred = listUnused2[i][1]
    predicted = np.dot(matrixAMovies_result[movie_id, :], matrixBUsers_result[:, user_id])
    print(f"Predicted rating for user {user_id} and movie {movie_id}: {predicted:.2f}     Actual {actualPred}")

# %%
learning_rate = np.float32(0.001)

# %%
for epoch in range(2):

    cuda.memcpy_htod(rows_gpu, rows_result)

    cuda.memcpy_htod(A_gpu_matrixAMovies, matrixAMovies_result)
    cuda.memcpy_htod(B_gpu_matrixBUsers, matrixBUsers_result)
    # learning_rate = np.float32(initial_lr * np.exp(-0.05 * epoch))



    matrixAMovies_result = np.empty_like(matrixAMovies)
    matrixBUsers_result = np.empty_like(matrixBUsers)
    rows_result = np.zeros(len(rows_data), dtype=[('col1', np.int32), ('col2', np.float32)])
    start_time = time.time()
    # if epoch % 5 == 0:  # Every 5 epochs, reduce learning rate
    #     learning_rate *= 0.9  # Reduce by 10%

    matmul(A_gpu_matrixAMovies, B_gpu_matrixBUsers, np.int32(N), np.int32(totalRaters),
           np.int32(totalMovies), rows_gpu, learning_rate, block=block_size, grid=grid_size,
           shared=shared_mem_size)
    
    cuda.Context.synchronize()  # Wait for CUDA execution

    # Copy updated matrices and rows back to CPU
    cuda.memcpy_dtoh(matrixAMovies_result, A_gpu_matrixAMovies)
    cuda.memcpy_dtoh(matrixBUsers_result, B_gpu_matrixBUsers)
    cuda.memcpy_dtoh(rows_result, rows_gpu)


    if np.isnan(matrixAMovies_result).any() or np.isnan(matrixBUsers_result).any():
        print("Error: NaN detected in A or B matrix!")
        exit()

    if np.isinf(matrixAMovies_result).any() or np.isinf(matrixBUsers_result).any():
        print("Error: Inf detected in A or B matrix!")
        exit()

    # Compute loss
    mse = 0
    count = 0
    for i in range(len(rows_result)):
        if rows_result[i]['col1'] > 0:
            actual = rows_result[i]['col2']
            predicted = np.dot(matrixAMovies_result[rows_result[i]['col1'], :], matrixBUsers_result[:, i // totalMoviesUsingPerPerson])
            
            if np.isnan(predicted) or np.isinf(predicted):
                print(f"Error in prediction: row {i}, actual {actual}, predicted {predicted}")
                exit()

            mse += (actual - predicted) ** 2
            count += 1

    mse = mse / count if count > 0 else float('inf')  # Avoid division by zero

    end_time = time.time()
    print(f"Epoch {epoch+1}/{epochs}, MSE: {mse:.5f}, Time: {end_time - start_time:.5f} sec")
# Out:
# Epoch 1/30, MSE: 1.34195, Time: 129.19257 sec
# Epoch 2/30, MSE: 1.34915, Time: 130.18946 sec

# %%
listUnused =[]
for m in (matrixrating[55:180]):
    hit=0
    for i in range(1*totalMoviesUsingPerPerson,2*totalMoviesUsingPerPerson):
        if int(m[1]) ==int(rows_data[i].col1):
            
            hit=1
            break
    if hit==0:
        listUnused.append([int(m[1]),int(m[2])])

listUnused2 =[]
for m in (matrixrating[55:180]):
    hit=0
    for i in range(1*totalMoviesUsingPerPerson,2*totalMoviesUsingPerPerson):
        if int(m[1]) ==int(rows_data[i].col1):
            
            hit=1
            break
    if hit==1:
        listUnused2.append([int(m[1]),float(m[2])])


print("HERE")
print()
for i in range(len(listUnused2)):
    user_id = 2  # Example user (change as needed)
    movie_id = listUnused2[i][0]  # Get the movie ID from rows_result
    actualPred = listUnused2[i][1]
    predicted = np.dot(matrixAMovies_result[movie_id, :], matrixBUsers_result[:, user_id])
    print(f"Predicted rating for user {user_id} and movie {movie_id}: {predicted:.2f}     Actual {actualPred}")
# Out:
# HERE
#
# Predicted rating for user 2 and movie 34: 5.10     Actual 5.0
# Predicted rating for user 2 and movie 39: 4.17     Actual 5.0
# Predicted rating for user 2 and movie 48: 4.39     Actual 5.0
# Predicted rating for user 2 and movie 153: 3.53     Actual 3.0
# Predicted rating for user 2 and movie 185: 4.40     Actual 5.0
# Predicted rating for user 2 and movie 186: 4.24     Actual 5.0
# Predicted rating for user 2 and movie 193: 2.89     Actual 3.0
# Predicted rating for user 2 and movie 207: 5.04     Actual 5.0
# Predicted rating for user 2 and movie 216: 2.87     Actual 4.0
# Predicted rating for user 2 and movie 218: 4.36     Actual 5.0
# Predicted rating for user 2 and movie 222: 4.61     Actual 5.0
# Predicted rating for user 2 and movie 225: 4.21     Actual 5.0
# Predicted rating for user 2 and movie 231: 2.02     Actual 2.0
# Predicted rating for user 2 and movie 236: 4.76     Actual 4.0
# Predicted rating for user 2 and movie 237: 4.22     Actual 5.0
# Predicted rating for user 2 and movie 253: 3.13     Actual 1.0
# Predicted rating for user 2 and movie 276: 4.10     Actual 4.0
# Predicted rating for user 2 and movie 282: 4.89     Actual 5.0
# Predicted rating for user 2 and movie 296: 2.86     Actual 1.0
# Predicted rating for user 2 and movie 305: 3.12     Actual 3.0
# Predicted rating for user 2 and movie 318: 4.66     Actual 5.0
# Predicted rating for user 2 and movie 339: 5.20     Actual 5.0
# Predicted rating for user 2 and movie 344: 2.43     Actual 1.0
# Predicted rating for user 2 and movie 349: 4.26     Actual 3.0
# Predicted rating for user 2 and movie 350: 4.66     Actual 5.0
# Predicted rating for user 2 and movie 356: 4.50     Actual 5.0
# Predicted rating for user 2 and movie 357: 4.43     Actual 4.0
# Predicted rating for user 2 and movie 362: 4.82     Actual 5.0
# Predicted rating for user 2 and movie 364: 4.40     Actual 5.0
# Predicted rating for user 2 and movie 377: 4.46     Actual 4.0
# Predicted rating for user 2 and movie 380: 4.06     Actual 5.0
# Predicted rating for user 2 and movie 381: 4.64     Actual 5.0
# Predicted rating for user 2 and movie 454: 4.44     Actual 4.0
# Predicted rating for user 2 and movie 457: 4.70     Actual 5.0
# Predicted rating for user 2 and movie 466: 3.22     Actual 3.0
# Predicted rating for user 2 and movie 500: 4.65     Actual 5.0
# Predicted rating for user 2 and movie 508: 4.80     Actual 5.0
# Predicted rating for user 2 and movie 520: 3.52     Actual 4.0

# %%
dictTest={}

for key, val in d.items():
    dictTest[key] = sorted(d[key][totalMoviesUsingPerPerson:], key=lambda x: x[0])

# %%
v=0
z=0
for key,val in dictTest.items():
    v+=len(val)
    if len(val)==0:
        z+=1
print(v)
print(z)
# Out:
# 7094487
# 183455

# %%
v=0
for key,val in newD.items():
    v+=len(val)
    
print(v)
# Out:
# 140
# 0
# 0

# %%
24704769+7094487
# Out:
# 31799256

# %%
print(len(matrixrating))
# Out:
# 32000204

# %%
mse=0
count=0
for key,val in dictTest.items():

    userID=key
    for row in val:
        movieID=int(row[0])
        actual = float(row[1])
        predicted = np.dot(matrixAMovies_result[movieID, :], matrixBUsers_result[:, userID // totalMoviesUsingPerPerson])
            
        if np.isnan(predicted) or np.isinf(predicted):
            print(f"Error in prediction: row {i}, actual {actual}, predicted {predicted}")
            exit()

        mse += (actual - predicted) ** 2
        count += 1
        print(f"Predicted rating for user {userID} and movie {movieID}: {predicted:.2f}     Actual {actual}")
        
mse = mse / count if count > 0 else float('inf')  # Avoid division by zero

print(f"MSE: {mse:.5f}")
# Out:
# MSE: 1.41328

# %% [markdown]
# KNN

# %%
def normalize_embeddings(matrix):
    norms = np.linalg.norm(matrix, axis=1, keepdims=True)
    norms[norms == 0] = 1  # Avoid division by zero
    return matrix / norms

normalized_movies = normalize_embeddings(matrixAMovies_result)

# def compute_cosine_similarity(matrix):
#     return np.dot(matrix, matrix.T)

# similarity_matrix = compute_cosine_similarity(normalized_movies)

# %%
def get_top_k_similar_movies_single(movie_id, normalized_movies, k=5):
    movie_vector = normalized_movies[movie_id]
    similarities = np.dot(normalized_movies, movie_vector)  # Only one movie
    top_k_indices = np.argsort(similarities)[-k-1:-1][::-1]  # Exclude itself
    return top_k_indices

# Usage:
top_k = get_top_k_similar_movies_single(movie_id=0, normalized_movies=normalized_movies, k=5)
print(top_k)
# Out:
# [257109 238977 270579 237718 245035]

# %%
def findMovie(id):
    print(f"{id} Movie name is {matrixMovies[id]}")

# %%
import numpy as np
import faiss

# Normalize
normalized_movies = normalize_embeddings(matrixAMovies_result)

# Build FAISS index
d = normalized_movies.shape[1]
index = faiss.IndexFlatIP(d)
index.add(normalized_movies)

# Search for similar movies
movie_id = 47
k = 5
query_vector = normalized_movies[movie_id:movie_id+1]

distances, indices = index.search(query_vector, k)

print(f"Top {k} similar movies to movie {movie_id} are: {indices.flatten()}")
print(f"Similarity scores: {distances.flatten()}")
# Out:
# Top 5 similar movies to movie 47 are: [ 47  50 296 293  32]
# Similarity scores: [0.99999994 0.9629129  0.9606562  0.9334225  0.91609144]

# %%
findMovie(movie_id)

print(f"Top {k} similar movies to movie {movie_id} are: {indices.flatten()}")
for id in indices.flatten():
    print(id,end=" ")
    findMovie(id)
# Out:
# Movie name is [48, 'Pocahontas (1995)', 'Animation|Children|Drama|Musical|Romance']
# Top 5 similar movies to movie 47 are: [ 47  50 296 293  32]
# 47 Movie name is [48, 'Pocahontas (1995)', 'Animation|Children|Drama|Musical|Romance']
# 50 Movie name is [51, 'Guardian Angel (1994)', 'Action|Drama|Thriller']
# 296 Movie name is [300, 'Quiz Show (1994)', 'Drama']
# 293 Movie name is [297, 'Panther (1995)', 'Drama']
# 32 Movie name is [33, 'Wings of Courage (1995)', 'Adventure|Romance|IMAX']

# %%
for i in range(300):
    findMovie(i)
# Out:
# 0 Movie name is [1, 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy']
# 1 Movie name is [2, 'Jumanji (1995)', 'Adventure|Children|Fantasy']
# 2 Movie name is [3, 'Grumpier Old Men (1995)', 'Comedy|Romance']
# 3 Movie name is [4, 'Waiting to Exhale (1995)', 'Comedy|Drama|Romance']
# 4 Movie name is [5, 'Father of the Bride Part II (1995)', 'Comedy']
# 5 Movie name is [6, 'Heat (1995)', 'Action|Crime|Thriller']
# 6 Movie name is [7, 'Sabrina (1995)', 'Comedy|Romance']
# 7 Movie name is [8, 'Tom and Huck (1995)', 'Adventure|Children']
# 8 Movie name is [9, 'Sudden Death (1995)', 'Action']
# 9 Movie name is [10, 'GoldenEye (1995)', 'Action|Adventure|Thriller']
# 10 Movie name is [11, '"American President', ' The (1995)"']
# 11 Movie name is [12, 'Dracula: Dead and Loving It (1995)', 'Comedy|Horror']
# 12 Movie name is [13, 'Balto (1995)', 'Adventure|Animation|Children']
# 13 Movie name is [14, 'Nixon (1995)', 'Drama']
# 14 Movie name is [15, 'Cutthroat Island (1995)', 'Action|Adventure|Romance']
# 15 Movie name is [16, 'Casino (1995)', 'Crime|Drama']
# 16 Movie name is [17, 'Sense and Sensibility (1995)', 'Drama|Romance']
# 17 Movie name is [18, 'Four Rooms (1995)', 'Comedy']
# 18 Movie name is [19, 'Ace Ventura: When Nature Calls (1995)', 'Comedy']
# 19 Movie name is [20, 'Money Train (1995)', 'Action|Comedy|Crime|Drama|Thriller']
# 20 Movie name is [21, 'Get Shorty (1995)', 'Comedy|Crime|Thriller']
# 21 Movie name is [22, 'Copycat (1995)', 'Crime|Drama|Horror|Mystery|Thriller']
# 22 Movie name is [23, 'Assassins (1995)', 'Action|Crime|Thriller']
# 23 Movie name is [24, 'Powder (1995)', 'Drama|Sci-Fi']
# 24 Movie name is [25, 'Leaving Las Vegas (1995)', 'Drama|Romance']
# 25 Movie name is [26, 'Othello (1995)', 'Drama']
# 26 Movie name is [27, 'Now and Then (1995)', 'Children|Drama']
# 27 Movie name is [28, 'Persuasion (1995)', 'Drama|Romance']
# 28 Movie name is [29, '"City of Lost Children', ' The (Cité des enfants perdus']
# 29 Movie name is [30, 'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)', 'Crime|Drama']
# 30 Movie name is [31, 'Dangerous Minds (1995)', 'Drama']
# 31 Movie name is [32, 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Mystery|Sci-Fi|Thriller']
# 32 Movie name is [33, 'Wings of Courage (1995)', 'Adventure|Romance|IMAX']
# 33 Movie name is [34, 'Babe (1995)', 'Children|Drama']
# 34 Movie name is [35, 'Carrington (1995)', 'Drama|Romance']
# 35 Movie name is [36, 'Dead Man Walking (1995)', 'Crime|Drama']
# 36 Movie name is [37, 'Across the Sea of Time (1995)', 'Documentary|IMAX']
# 37 Movie name is [38, 'It Takes Two (1995)', 'Children|Comedy']
# 38 Movie name is [39, 'Clueless (1995)', 'Comedy|Romance']
# 39 Movie name is [40, '"Cry', ' the Beloved Country (1995)"']
# 40 Movie name is [41, 'Richard III (1995)', 'Drama|War']
# 41 Movie name is [42, 'Dead Presidents (1995)', 'Action|Crime|Drama']
# 42 Movie name is [43, 'Restoration (1995)', 'Drama']
# 43 Movie name is [44, 'Mortal Kombat (1995)', 'Action|Adventure|Fantasy']
# 44 Movie name is [45, 'To Die For (1995)', 'Comedy|Drama|Thriller']
# 45 Movie name is [46, 'How to Make an American Quilt (1995)', 'Drama|Romance']
# 46 Movie name is [47, 'Seven (a.k.a. Se7en) (1995)', 'Mystery|Thriller']
# 47 Movie name is [48, 'Pocahontas (1995)', 'Animation|Children|Drama|Musical|Romance']
# 48 Movie name is [49, 'When Night Is Falling (1995)', 'Drama|Romance']
# 49 Movie name is [50, '"Usual Suspects', ' The (1995)"']
# 50 Movie name is [51, 'Guardian Angel (1994)', 'Action|Drama|Thriller']
# 51 Movie name is [52, 'Mighty Aphrodite (1995)', 'Comedy|Drama|Romance']
# 52 Movie name is [53, 'Lamerica (1994)', 'Adventure|Drama']
# 53 Movie name is [54, '"Big Green', ' The (1995)"']
# 54 Movie name is [55, 'Georgia (1995)', 'Drama']
# 55 Movie name is [56, 'Kids of the Round Table (1995)', 'Adventure|Children|Comedy|Fantasy']
# 56 Movie name is [57, 'Home for the Holidays (1995)', 'Drama']
# 57 Movie name is [58, '"Postman', ' The (Postino']
# 58 Movie name is [59, '"Confessional', ' The (Confessionnal']
# 59 Movie name is [60, '"Indian in the Cupboard', ' The (1995)"']
# 60 Movie name is [61, 'Eye for an Eye (1996)', 'Drama|Thriller']
# 61 Movie name is [62, "Mr. Holland's Opus (1995)", 'Drama']
# 62 Movie name is [63, "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)", 'Comedy|Crime']
# 63 Movie name is [64, 'Two if by Sea (1996)', 'Comedy|Romance']
# 64 Movie name is [65, 'Bio-Dome (1996)', 'Comedy']
# 65 Movie name is [66, 'Lawnmower Man 2: Beyond Cyberspace (1996)', 'Action|Sci-Fi|Thriller']
# 66 Movie name is [67, 'Two Bits (1995)', 'Drama']
# 67 Movie name is [68, 'French Twist (Gazon maudit) (1995)', 'Comedy|Romance']
# 68 Movie name is [69, 'Friday (1995)', 'Comedy']
# 69 Movie name is [70, 'From Dusk Till Dawn (1996)', 'Action|Comedy|Horror|Thriller']
# 70 Movie name is [71, 'Fair Game (1995)', 'Action']
# 71 Movie name is [72, 'Kicking and Screaming (1995)', 'Comedy|Drama']
# 72 Movie name is [73, '"Misérables', ' Les (1995)"']
# 73 Movie name is [74, 'Bed of Roses (1996)', 'Drama|Romance']
# 74 Movie name is [75, 'Big Bully (1996)', 'Comedy|Drama']
# 75 Movie name is [76, 'Screamers (1995)', 'Action|Sci-Fi|Thriller']
# 76 Movie name is [77, 'Nico Icon (1995)', 'Documentary']
# 77 Movie name is [78, '"Crossing Guard', ' The (1995)"']
# 78 Movie name is [79, '"Juror', ' The (1996)"']
# 79 Movie name is [80, '"White Balloon', ' The (Badkonake sefid) (1995)"']
# 80 Movie name is [81, "Things to Do in Denver When You're Dead (1995)", 'Crime|Drama|Romance']
# 81 Movie name is [82, "Antonia's Line (Antonia) (1995)", 'Comedy|Drama']
# 82 Movie name is [83, 'Once Upon a Time... When We Were Colored (1995)', 'Drama|Romance']
# 83 Movie name is [84, 'Last Summer in the Hamptons (1995)', 'Comedy|Drama']
# 84 Movie name is [85, 'Angels and Insects (1995)', 'Drama|Romance']
# 85 Movie name is [86, 'White Squall (1996)', 'Action|Adventure|Drama']
# 86 Movie name is [87, 'Dunston Checks In (1996)', 'Children|Comedy']
# 87 Movie name is [88, 'Black Sheep (1996)', 'Comedy']
# 88 Movie name is [89, 'Nick of Time (1995)', 'Action|Thriller']
# 89 Movie name is [90, 'The Journey of August King (1995)', 'Drama']
# 90 Movie name is [92, 'Mary Reilly (1996)', 'Drama|Horror|Thriller']
# 91 Movie name is [93, 'Vampire in Brooklyn (1995)', 'Comedy|Horror|Romance']
# 92 Movie name is [94, 'Beautiful Girls (1996)', 'Comedy|Drama|Romance']
# 93 Movie name is [95, 'Broken Arrow (1996)', 'Action|Adventure|Thriller']
# 94 Movie name is [96, 'In the Bleak Midwinter (1995)', 'Comedy|Drama']
# 95 Movie name is [97, '"Hate (Haine', ' La) (1995)"']
# 96 Movie name is [98, 'Shopping (1994)', 'Action|Thriller']
# 97 Movie name is [99, 'Heidi Fleiss: Hollywood Madam (1995)', 'Documentary']
# 98 Movie name is [100, 'City Hall (1996)', 'Drama|Thriller']
# 99 Movie name is [101, 'Bottle Rocket (1996)', 'Adventure|Comedy|Crime|Romance']
# 100 Movie name is [102, 'Mr. Wrong (1996)', 'Comedy']
# 101 Movie name is [103, 'Unforgettable (1996)', 'Mystery|Sci-Fi|Thriller']
# 102 Movie name is [104, 'Happy Gilmore (1996)', 'Comedy']
# 103 Movie name is [105, '"Bridges of Madison County', ' The (1995)"']
# 104 Movie name is [106, 'Nobody Loves Me (Keiner liebt mich) (1994)', 'Comedy|Drama']
# 105 Movie name is [107, 'Muppet Treasure Island (1996)', 'Adventure|Children|Comedy|Musical']
# 106 Movie name is [108, 'Catwalk (1996)', 'Documentary']
# 107 Movie name is [109, 'Headless Body in Topless Bar (1995)', 'Comedy|Drama|Thriller']
# 108 Movie name is [110, 'Braveheart (1995)', 'Action|Drama|War']
# 109 Movie name is [111, 'Taxi Driver (1976)', 'Crime|Drama|Thriller']
# 110 Movie name is [112, 'Rumble in the Bronx (Hont faan kui) (1995)', 'Action|Adventure|Comedy|Crime']
# 111 Movie name is [113, 'Before and After (1996)', 'Drama|Mystery']
# 112 Movie name is [114, "Margaret's Museum (1995)", 'Drama']
# 113 Movie name is [115, '"Happiness Is in the Field (Bonheur est dans le pré', ' Le) (1995)"']
# 114 Movie name is [116, 'Anne Frank Remembered (1995)', 'Documentary']
# 115 Movie name is [117, '"Young Poisoner\'s Handbook', ' The (1995)"']
# 116 Movie name is [118, 'If Lucy Fell (1996)', 'Comedy|Romance']
# 117 Movie name is [119, '"Steal Big', ' Steal Little (1995)"']
# 118 Movie name is [120, 'Race the Sun (1996)', 'Adventure|Comedy|Drama']
# 119 Movie name is [121, '"Boys of St. Vincent', ' The (1992)"']
# 120 Movie name is [122, 'Boomerang (1992)', 'Comedy|Romance']
# 121 Movie name is [123, 'Chungking Express (Chung Hing sam lam) (1994)', 'Drama|Mystery|Romance']
# 122 Movie name is [124, '"Star Maker', ' The (Uomo delle stelle']
# 123 Movie name is [125, 'Flirting With Disaster (1996)', 'Comedy']
# 124 Movie name is [126, '"NeverEnding Story III', ' The (1994)"']
# 125 Movie name is [127, '"Silences of the Palace', ' The (Saimt el Qusur) (1994)"']
# 126 Movie name is [128, "Jupiter's Wife (1994)", 'Documentary']
# 127 Movie name is [129, 'Pie in the Sky (1996)', 'Comedy|Romance']
# 128 Movie name is [130, 'Angela (1995)', 'Drama']
# 129 Movie name is [131, 'Frankie Starlight (1995)', 'Drama|Romance']
# 130 Movie name is [132, 'Jade (1995)', 'Thriller']
# 131 Movie name is [133, 'Nueba Yol (1995)', 'Comedy|Drama']
# 132 Movie name is [134, 'Sonic Outlaws (1995)', 'Documentary']
# 133 Movie name is [135, 'Down Periscope (1996)', 'Comedy']
# 134 Movie name is [136, 'From the Journals of Jean Seberg (1995)', 'Documentary']
# 135 Movie name is [137, 'Man of the Year (1995)', 'Documentary']
# 136 Movie name is [138, '"Neon Bible', ' The (1995)"']
# 137 Movie name is [139, 'Target (1995)', 'Action|Drama']
# 138 Movie name is [140, 'Up Close and Personal (1996)', 'Drama|Romance']
# 139 Movie name is [141, '"Birdcage', ' The (1996)"']
# 140 Movie name is [142, 'Shadows (Cienie) (1988)', 'Drama']
# 141 Movie name is [143, 'Gospa (1995)', 'Drama']
# 142 Movie name is [144, '"Brothers McMullen', ' The (1995)"']
# 143 Movie name is [145, 'Bad Boys (1995)', 'Action|Comedy|Crime|Drama|Thriller']
# 144 Movie name is [146, '"Amazing Panda Adventure', ' The (1995)"']
# 145 Movie name is [147, '"Basketball Diaries', ' The (1995)"']
# 146 Movie name is [148, '"Awfully Big Adventure', ' An (1995)"']
# 147 Movie name is [149, 'Amateur (1994)', 'Crime|Drama|Thriller']
# 148 Movie name is [150, 'Apollo 13 (1995)', 'Adventure|Drama|IMAX']
# 149 Movie name is [151, 'Rob Roy (1995)', 'Action|Drama|Romance|War']
# 150 Movie name is [152, '"Addiction', ' The (1995)"']
# 151 Movie name is [153, 'Batman Forever (1995)', 'Action|Adventure|Comedy|Crime']
# 152 Movie name is [154, 'Beauty of the Day (Belle de jour) (1967)', 'Drama']
# 153 Movie name is [155, 'Beyond Rangoon (1995)', 'Adventure|Drama|War']
# 154 Movie name is [156, 'Blue in the Face (1995)', 'Comedy|Drama']
# 155 Movie name is [157, 'Canadian Bacon (1995)', 'Comedy|War']
# 156 Movie name is [158, 'Casper (1995)', 'Adventure|Children']
# 157 Movie name is [159, 'Clockers (1995)', 'Crime|Drama|Mystery']
# 158 Movie name is [160, 'Congo (1995)', 'Action|Adventure|Mystery|Sci-Fi']
# 159 Movie name is [161, 'Crimson Tide (1995)', 'Drama|Thriller|War']
# 160 Movie name is [162, 'Crumb (1994)', 'Documentary']
# 161 Movie name is [163, 'Desperado (1995)', 'Action|Romance|Western']
# 162 Movie name is [164, 'Devil in a Blue Dress (1995)', 'Crime|Film-Noir|Mystery|Thriller']
# 163 Movie name is [165, 'Die Hard: With a Vengeance (1995)', 'Action|Crime|Thriller']
# 164 Movie name is [166, '"Doom Generation', ' The (1995)"']
# 165 Movie name is [167, 'Feast of July (1995)', 'Drama']
# 166 Movie name is [168, 'First Knight (1995)', 'Action|Drama|Romance']
# 167 Movie name is [169, 'Free Willy 2: The Adventure Home (1995)', 'Adventure|Children|Drama']
# 168 Movie name is [170, 'Hackers (1995)', 'Action|Adventure|Crime|Thriller']
# 169 Movie name is [171, 'Jeffrey (1995)', 'Comedy|Drama']
# 170 Movie name is [172, 'Johnny Mnemonic (1995)', 'Action|Sci-Fi|Thriller']
# 171 Movie name is [173, 'Judge Dredd (1995)', 'Action|Crime|Sci-Fi']
# 172 Movie name is [174, 'Jury Duty (1995)', 'Comedy']
# 173 Movie name is [175, 'Kids (1995)', 'Drama']
# 174 Movie name is [176, 'Living in Oblivion (1995)', 'Comedy']
# 175 Movie name is [177, 'Lord of Illusions (1995)', 'Horror']
# 176 Movie name is [178, 'Love & Human Remains (1993)', 'Comedy|Drama']
# 177 Movie name is [179, 'Mad Love (1995)', 'Drama|Romance']
# 178 Movie name is [180, 'Mallrats (1995)', 'Comedy|Romance']
# 179 Movie name is [181, 'Mighty Morphin Power Rangers: The Movie (1995)', 'Action|Children']
# 180 Movie name is [182, 'Moonlight and Valentino (1995)', 'Drama|Romance']
# 181 Movie name is [183, 'Mute Witness (1994)', 'Comedy|Horror|Thriller']
# 182 Movie name is [184, 'Nadja (1994)', 'Drama']
# 183 Movie name is [185, '"Net', ' The (1995)"']
# 184 Movie name is [186, 'Nine Months (1995)', 'Comedy|Romance']
# 185 Movie name is [187, 'Party Girl (1995)', 'Comedy']
# 186 Movie name is [188, '"Prophecy', ' The (1995)"']
# 187 Movie name is [189, 'Reckless (1995)', 'Comedy|Fantasy']
# 188 Movie name is [190, 'Safe (1995)', 'Thriller']
# 189 Movie name is [191, '"Scarlet Letter', ' The (1995)"']
# 190 Movie name is [192, 'The Show (1995)', 'Documentary']
# 191 Movie name is [193, 'Showgirls (1995)', 'Drama']
# 192 Movie name is [194, 'Smoke (1995)', 'Comedy|Drama']
# 193 Movie name is [195, 'Something to Talk About (1995)', 'Comedy|Drama|Romance']
# 194 Movie name is [196, 'Species (1995)', 'Horror|Sci-Fi']
# 195 Movie name is [197, '"Stars Fell on Henrietta', ' The (1995)"']
# 196 Movie name is [198, 'Strange Days (1995)', 'Action|Crime|Drama|Mystery|Sci-Fi|Thriller']
# 197 Movie name is [199, '"Umbrellas of Cherbourg', ' The (Parapluies de Cherbourg']
# 198 Movie name is [200, '"Tie That Binds', ' The (1995)"']
# 199 Movie name is [201, 'Three Wishes (1995)', 'Drama|Fantasy']
# 200 Movie name is [202, 'Total Eclipse (1995)', 'Drama|Romance']
# 201 Movie name is [203, '"To Wong Foo', ' Thanks for Everything! Julie Newmar (1995)"']
# 202 Movie name is [204, 'Under Siege 2: Dark Territory (1995)', 'Action']
# 203 Movie name is [205, 'Unstrung Heroes (1995)', 'Comedy|Drama']
# 204 Movie name is [206, 'Unzipped (1995)', 'Documentary']
# 205 Movie name is [207, '"Walk in the Clouds', ' A (1995)"']
# 206 Movie name is [208, 'Waterworld (1995)', 'Action|Adventure|Sci-Fi']
# 207 Movie name is [209, "White Man's Burden (1995)", 'Drama']
# 208 Movie name is [210, 'Wild Bill (1995)', 'Western']
# 209 Movie name is [211, '"Browning Version', ' The (1994)"']
# 210 Movie name is [212, 'Bushwhacked (1995)', 'Adventure|Comedy|Crime|Mystery']
# 211 Movie name is [213, 'Burnt by the Sun (Utomlyonnye solntsem) (1994)', 'Drama']
# 212 Movie name is [214, 'Before the Rain (Pred dozhdot) (1994)', 'Drama|War']
# 213 Movie name is [215, 'Before Sunrise (1995)', 'Drama|Romance']
# 214 Movie name is [216, 'Billy Madison (1995)', 'Comedy']
# 215 Movie name is [217, '"Babysitter', ' The (1995)"']
# 216 Movie name is [218, 'Boys on the Side (1995)', 'Comedy|Drama']
# 217 Movie name is [219, '"Cure', ' The (1995)"']
# 218 Movie name is [220, 'Castle Freak (1995)', 'Horror']
# 219 Movie name is [222, 'Circle of Friends (1995)', 'Drama|Romance']
# 220 Movie name is [223, 'Clerks (1994)', 'Comedy']
# 221 Movie name is [224, 'Don Juan DeMarco (1995)', 'Comedy|Drama|Romance']
# 222 Movie name is [225, 'Disclosure (1994)', 'Drama|Thriller']
# 223 Movie name is [226, 'Dream Man (1995)', 'Thriller']
# 224 Movie name is [227, 'Drop Zone (1994)', 'Action|Thriller']
# 225 Movie name is [228, 'Destiny Turns on the Radio (1995)', 'Comedy']
# 226 Movie name is [229, 'Death and the Maiden (1994)', 'Drama|Thriller']
# 227 Movie name is [230, 'Dolores Claiborne (1995)', 'Drama|Thriller']
# 228 Movie name is [231, 'Dumb & Dumber (Dumb and Dumber) (1994)', 'Adventure|Comedy']
# 229 Movie name is [232, 'Eat Drink Man Woman (Yin shi nan nu) (1994)', 'Comedy|Drama|Romance']
# 230 Movie name is [233, 'Exotica (1994)', 'Drama']
# 231 Movie name is [234, 'Exit to Eden (1994)', 'Comedy']
# 232 Movie name is [235, 'Ed Wood (1994)', 'Comedy|Drama']
# 233 Movie name is [236, 'French Kiss (1995)', 'Action|Comedy|Romance']
# 234 Movie name is [237, 'Forget Paris (1995)', 'Comedy|Romance']
# 235 Movie name is [238, 'Far From Home: The Adventures of Yellow Dog (1995)', 'Adventure|Children']
# 236 Movie name is [239, '"Goofy Movie', ' A (1995)"']
# 237 Movie name is [240, 'Hideaway (1995)', 'Thriller']
# 238 Movie name is [241, 'Fluke (1995)', 'Children|Drama']
# 239 Movie name is [242, 'Farinelli: il castrato (1994)', 'Drama|Musical']
# 240 Movie name is [243, 'Gordy (1995)', 'Children|Comedy|Fantasy']
# 241 Movie name is [244, 'Gumby: The Movie (1995)', 'Animation|Children']
# 242 Movie name is [245, 'The Glass Shield (1994)', 'Crime|Drama']
# 243 Movie name is [246, 'Hoop Dreams (1994)', 'Documentary']
# 244 Movie name is [247, 'Heavenly Creatures (1994)', 'Crime|Drama']
# 245 Movie name is [248, 'Houseguest (1994)', 'Comedy']
# 246 Movie name is [249, 'Immortal Beloved (1994)', 'Drama|Romance']
# 247 Movie name is [250, 'Heavyweights (Heavy Weights) (1995)', 'Children|Comedy']
# 248 Movie name is [251, '"Hunted', ' The (1995)"']
# 249 Movie name is [252, 'I.Q. (1994)', 'Comedy|Romance']
# 250 Movie name is [253, 'Interview with the Vampire: The Vampire Chronicles (1994)', 'Drama|Horror']
# 251 Movie name is [254, 'Jefferson in Paris (1995)', 'Drama']
# 252 Movie name is [255, '"Jerky Boys', ' The (1995)"']
# 253 Movie name is [256, 'Junior (1994)', 'Comedy|Sci-Fi']
# 254 Movie name is [257, 'Just Cause (1995)', 'Mystery|Thriller']
# 255 Movie name is [258, '"Kid in King Arthur\'s Court', ' A (1995)"']
# 256 Movie name is [259, 'Kiss of Death (1995)', 'Crime|Drama|Thriller']
# 257 Movie name is [260, 'Star Wars: Episode IV - A New Hope (1977)', 'Action|Adventure|Sci-Fi']
# 258 Movie name is [261, 'Little Women (1994)', 'Drama']
# 259 Movie name is [262, '"Little Princess', ' A (1995)"']
# 260 Movie name is [263, 'Ladybird Ladybird (1994)', 'Drama']
# 261 Movie name is [264, '"Enfer', ' L\' (1994)"']
# 262 Movie name is [265, 'Like Water for Chocolate (Como agua para chocolate) (1992)', 'Drama|Fantasy|Romance']
# 263 Movie name is [266, 'Legends of the Fall (1994)', 'Drama|Romance|War|Western']
# 264 Movie name is [267, 'Major Payne (1995)', 'Comedy']
# 265 Movie name is [268, 'Little Odessa (1994)', 'Crime|Drama']
# 266 Movie name is [269, 'My Crazy Life (Mi vida loca) (1993)', 'Drama']
# 267 Movie name is [270, 'Love Affair (1994)', 'Drama|Romance']
# 268 Movie name is [271, 'Losing Isaiah (1995)', 'Drama']
# 269 Movie name is [272, '"Madness of King George', ' The (1994)"']
# 270 Movie name is [273, "Mary Shelley's Frankenstein (Frankenstein) (1994)", 'Drama|Horror|Sci-Fi']
# 271 Movie name is [274, 'Man of the House (1995)', 'Comedy']
# 272 Movie name is [275, 'Mixed Nuts (1994)', 'Comedy']
# 273 Movie name is [276, 'Milk Money (1994)', 'Comedy|Romance']
# 274 Movie name is [277, 'Miracle on 34th Street (1994)', 'Drama']
# 275 Movie name is [278, 'Miami Rhapsody (1995)', 'Comedy']
# 276 Movie name is [279, 'My Family (1995)', 'Drama']
# 277 Movie name is [280, 'Murder in the First (1995)', 'Drama|Thriller']
# 278 Movie name is [281, "Nobody's Fool (1994)", 'Comedy|Drama|Romance']
# 279 Movie name is [282, 'Nell (1994)', 'Drama']
# 280 Movie name is [283, 'New Jersey Drive (1995)', 'Crime|Drama']
# 281 Movie name is [284, 'New York Cop (Nyû Yôku no koppu) (1993)', 'Action|Crime']
# 282 Movie name is [285, 'Beyond Bedlam (1993)', 'Drama|Horror']
# 283 Movie name is [286, 'Nemesis 2: Nebula (1995)', 'Action|Sci-Fi|Thriller']
# 284 Movie name is [287, 'Nina Takes a Lover (1994)', 'Comedy|Romance']
# 285 Movie name is [288, 'Natural Born Killers (1994)', 'Action|Crime|Thriller']
# 286 Movie name is [289, 'Only You (1994)', 'Comedy|Romance']
# 287 Movie name is [290, 'Once Were Warriors (1994)', 'Crime|Drama']
# 288 Movie name is [292, 'Outbreak (1995)', 'Action|Drama|Sci-Fi|Thriller']
# 289 Movie name is [293, 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Action|Crime|Drama|Thriller']
# 290 Movie name is [294, '"Perez Family', ' The (1995)"']
# 291 Movie name is [295, '"Pyromaniac\'s Love Story', ' A (1995)"']
# 292 Movie name is [296, 'Pulp Fiction (1994)', 'Comedy|Crime|Drama|Thriller']
# 293 Movie name is [297, 'Panther (1995)', 'Drama']
# 294 Movie name is [298, 'Pushing Hands (Tui shou) (1992)', 'Drama']
# 295 Movie name is [299, 'Priest (1994)', 'Drama']
# 296 Movie name is [300, 'Quiz Show (1994)', 'Drama']
# 297 Movie name is [301, 'Picture Bride (Bijo photo) (1994)', 'Drama|Romance']
# 298 Movie name is [302, '"Queen Margot (Reine Margot', ' La) (1994)"']
# 299 Movie name is [303, '"Quick and the Dead', ' The (1995)"']
